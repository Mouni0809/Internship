# %%
#Ques 1

import selenium
import pandas as pd
from selenium import webdriver
import time
from selenium.webdriver.common.by import By
import requests
from selenium.common.exceptions import NoSuchElementException
from tqdm import tqdm

# %%
driver = webdriver.Chrome()
driver.get("https://www.amazon.in/")

# %%
ser = input()
# Out:
# guitar

# %%
x=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input")
x.send_keys(ser)

search=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search.click()

# %%
#Ques 2

Brand = []
Product = []
Price = []
exchange = []
Expected_Delivery = []
availability = []
URL = []

# %%
# range(0,3) used to scrape three pages on website
for j in range(0,3):
    url=driver.find_elements(By.XPATH,'//a[@class="a-link-normal s-underline-text s-underline-link-text s-link-style a-text-normal"]')
    for i in url:
        URL.append(i.get_attribute('href'))
    time.sleep(2)
    # locating next page button and clicking
    url = f"https://www.amazon.in/s?k=guitars&page={j}&crid=2D4YVS8PMV5D9&qid=1695988712&sprefix=%2Caps%2C234&ref=sr_pg_{j}"
    response = requests.get(url)

# %%
for i in tqdm(URL):
    
    driver.get(i)    
    try:
        brand=driver.find_element(By.XPATH,'//a[@id="bylineInfo"]')
        Brand.append(brand.text) 
    except:
        Brand.append('-')
        
   
    try:
        pro =driver.find_element(By.XPATH,'//span[@id="productTitle"]')
        Product.append(pro.text)
    except:
        Product.append('-')
    time.sleep(1)
    
    
    try:
        price=driver.find_element(By.XPATH,'//span[@class="a-price aok-align-center"]')
        Price.append(price.text)
    except:
        Price.append('-')
    time.sleep(1)
    
    try:
        replacement=driver.find_element(By.XPATH,'//*[@id="RETURNS_POLICY"]/span/div[2]/a')
        exchange.append(replacement.text)
    except:
        exchange.append('-')
    time.sleep(1)
    

    try:
        delivery=driver.find_element(By.XPATH,'//div[@id="deliveryBlockMessage"]')
        Expected_Delivery.append(delivery.text)
    except:
        Expected_Delivery.append('-')
    time.sleep(1)
    

    try:
        avail=driver.find_element(By.XPATH,'//span[@class="a-size-medium a-color-success"]')
        availability.append(avail.text)
    except:
        availability.append('-')
    time.sleep(1)
# Out:
# 100%|██████████| 180/180 [25:47<00:00,  8.60s/it]

# %%
Guitar=pd.DataFrame({'Brand':Brand,'Product':Product,'Price':Price,
                        'Return/Exchange':exchange,'Expected Delivery':Expected_Delivery,'Availability':availability,
                        'URL':URL})
print('\033[1m'+'Guitar Details :'+'\033[0m')
Guitar
# Out:
# Guitar Details :
#                        Brand  \
# 0    Visit the Kadence Store
# 1     Visit the Henrix Store
# 2    Visit the Kadence Store
# 3               Brand: REVEL
# 4     Visit the JUAREZ Store
# ..                       ...
# 175   Visit the Henrix Store
# 176    Visit the VAULT Store
# 177           Brand: Generic
# 178           Brand: Generic
# 179      Brand: allmusicmart
#
#                                                Product       Price  \
# 0    Kadence rosewood Guitar Frontier Series, Elect...  ₹4,999\n00
# 1    Henrix 38C 38 Inch Cutaway Acoustic Guitar Wit...  ₹2,999\n00
# 2    Kadence Frontier guitar with Online Guitar lea...  ₹4,299\n00
# 3    Revel 38 Inches Cutaway Design Acoustic Guitar...  ₹2,761\n00
# 4    Juârez Acoustic Guitar, 38 Inch Cutaway, 038C ...  ₹1,899\n00
# ..                                                 ...         ...
# 175  Henrix 38C 38 Inch Left Handed Cutaway Acousti...  ₹2,999\n00
# ...

# %%
//END

# %%
#Ques 4

driver = webdriver.Chrome()
driver.get("http://www.flipkart.com/")

# %%
close=driver.find_element(By.XPATH,"/html/body/div[3]/div/span")
close.click()

# %%
x=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/div/input")
x.send_keys("smartphones")

search=driver.find_element(By.XPATH,"/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/header/div[1]/div[2]/form/div/button")
search.click()

# %%
Brand =[]
Smartphone =[]
Colour =[]
Storage_Rom =[]
Primary_camera=[]
Secondary_camera=[]
Display_size=[]
Display_resolution=[]
Processor =[]
Processor_cores=[]
Battery_capacity=[]
Price =[]

# %%
URL=[]
url=driver.find_elements(By.XPATH,'//a[@class="_1fQZEK"]')
for i in url:
    Href=i.get_attribute('href')
    URL.append(Href)

# %%
from tqdm import tqdm
for i in tqdm(URL):
    driver.get(i)
    time.sleep(3)
    
    # Expanding specification table by clicking on read more button
    try:
        Read_more=driver.find_element(By.XPATH,'//button[@class="_2KpZ6l _1FH0tX"]')
        Read_more.click()
        
    except NoSuchElementException:
        print('NoSuchElementException Occur')
        pass
    
    # Extracting Brand Name via Xpath
    try:
        brand=driver.find_element(By.XPATH,'//span[@class="B_NuCI"]')
        Brand.append(brand.text.split()[0])
    
    except NoSuchElementException:
        Brand.append('-')
        
    # Extracting Smartphone Model via Xpath
    try:
        smartphone=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[3]/td[2]/ul/li')
        Smartphone.append(smartphone.text)
    
    except NoSuchElementException:
        Smartphone.append('-')
        
    # Extracting Colour via Xpath
    try:
        colour=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][1]/table/tbody/tr[4]/td[2]/ul/li')
        Colour.append(colour.text)
    
    except NoSuchElementException:
        Colour.append('-')
    
    # Extracting Storage Rom via Xpath
    try:
        Rom=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][4]/table/tbody/tr[1]/td[2]/ul/li')
        Storage_Rom.append(Rom.text)
        
    except NoSuchElementException:
        Storage_Rom.append('Not Mention')
        
    # Extracting primary camera detail via Xpath
    try:
        primary_camera=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[2]/td[2]/ul/li')
        Primary_camera.append(primary_camera.text)
    
    except NoSuchElementException:
        Primary_camera.append('Not Mention')
        
    # Extracting Secondary Camera detail via Xpath
    try:
        secondary_cam=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][5]/table/tbody/tr[5]/td[2]/ul/li')
        Secondary_camera.append(secondary_cam.text)
    
    except NoSuchElementException:
        Secondary_camera.append('Not Mention')
    
    # Extracting Display size via Xpath
    try:
        display=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table/tbody/tr[1]/td[2]/ul/li')
        Display_size.append(display.text)
    except NoSuchElementException:
        Display_size.append('-')
    
    # Extracting Display Resolution via Xpath
    try:
        resolution=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][2]/table/tbody/tr[2]/td[2]/ul/li')
        Display_resolution.append(resolution.text)
    except NoSuchElementException:
        Display_resolution.append('-')
    
    # Extracting processor detail via xpath
    try:
        processor=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table/tbody/tr[2]/td[2]/ul/li')
        Processor.append(processor.text)
    
    except NoSuchElementException:
        Processor.append('-')
        
    # Extracting Processor core via xpath
    try:
        core=driver.find_element(By.XPATH,'//div[@class="_3k-BhJ"][3]/table/tbody/tr[3]/td[2]/ul/li')
        Processor_cores.append(core.text)
    except NoSuchElementException:
        Processor_cores.append('Not Mention')
    
    #Extracting Price via X path
    try:
        price=driver.find_element(By.XPATH,'//div[@class="_30jeq3 _16Jk6d"]')
        Price.append(price.text)
    except NoSuchElementException:
        Price.append('Not Mention')
# Out:
# 100%|██████████| 24/24 [02:01<00:00,  5.08s/it]

# %%
smartphone=pd.DataFrame({'Brand':Brand,'Smartphone':Smartphone,'Colour':Colour,'Price':Price,
                        'Storage Rom':Storage_Rom,'Primary Camera':Primary_camera,'Display Size':Display_size,
                        'Display Resolution':Display_resolution,'Processor':Processor,'Processor Cores':Processor_cores})
print('\033[1m'+'Flipkart Iphone Models :'+'\033[0m')
smartphone
# Out:
# Flipkart Iphone Models :
#        Brand         Smartphone            Colour    Price Storage Rom  \
# 0   MOTOROLA        Edge 40 Neo      Black Beauty  ₹22,999      256 GB
# 1   MOTOROLA                e13      Aurora Green   ₹7,499      128 GB
# 2   MOTOROLA                e13      Aurora Green   ₹6,499       64 GB
# 3       POCO                C51        Royal Blue   ₹5,999       64 GB
# 4       POCO                 M5       Power Black   ₹7,777       64 GB
# 5      APPLE          iPhone 13          Midnight  ₹52,499      128 GB
# 6   MOTOROLA             g84 5G  Marshmallow Blue  ₹17,999      256 GB
# 7    OnePlus  Nord CE 2 Lite 5G         Blue Tide  ₹17,050      128 GB
# 8    SAMSUNG         Galaxy F13    Waterfall Blue  ₹10,199      128 GB
# 9    OnePlus  Nord CE 3 Lite 5G    Chromatic Gray  ₹21,999      256 GB
# 10   OnePlus  Nord CE 3 Lite 5G       Pastel Lime  ₹21,989      256 GB
# 11   OnePlus  Nord CE 3 Lite 5G    Chromatic Gray  ₹19,999      128 GB
# ...

# %%
//END

# %%
# Ques 5

driver = webdriver.Chrome()
url = "https://www.google.com/maps/"
driver.get(url)

# %%
x=driver.find_element(By.XPATH,"/html/body/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/form/input")
x.send_keys("Bangalore")

search=driver.find_element(By.XPATH,"/html/body/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/div[1]/button")
search.click()

# %%
#using current_url method to get the current URL
get_url=driver.current_url

if "@" in get_url:
        value=get_url.split('@')[1].split(',*/data')[0].split(',')
        print('Latitude  :',value[0])
        print('Longitude :',value[1])
# Out:
# Latitude  : 12.9539456
# Longitude : 77.4661262

# %%
//END

# %%
# Ques 6

driver = webdriver.Chrome()
url='https://www.digit.in'
driver.get(url)

# %%
top=driver.find_element(By.XPATH,"/html/body/div[1]/header/div/div[1]/div/div/nav/ul/li[3]")
top.click()

best_lap=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div/div[2]/div[1]/div[2]/div[6]/p")
best_lap.click()
time.sleep(2)

# %%
gaming=driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/div/aside[2]/div[3]/div[2]/div/div[4]/div/h5")
gaming.click()

# %%
model =[]
OS =[]
Display = []
Processor =[]
Price =[]

# %%
try:
    mod=driver.find_elements(By.XPATH, '//div[@class="rh_gr_top_middle mb10 colored_rate_bar"]')
    for i in mod[0:8]:
        m=i.text
        model.append(m)
except:
    model.append('Not Mention')

try:  
    os=driver.find_elements(By.XPATH, '//div[@class="rh_grid_image_3_col"]/div[3]/div[2]/div[1]/div[1]/span[2]')
    for i in os[0:8]:
        o=i.text
        OS.append(o)

except:
    OS.append('-')
    
try:
    display=driver.find_elements(By.XPATH, '//div[@class="rh_grid_image_3_col"]/div[3]/div[2]/div[2]/div[1]/span[2]')
    for i in display[0:8]:
        d=i.text
        Display.append(d)    

except:
    Display.append('Not Mention')
    
try:  
    pro=driver.find_elements(By.XPATH, '//div[@class="rh_grid_image_3_col"]/div[3]/div[2]/div[4]/div[1]/span[2]')
    for i in pro[0:8]:
        p=i.text
        Processor.append(p)

except:
    Processor.append('Not Mention')
    
    
try:
    price=driver.find_elements(By.XPATH, '//div[@class="cegg-price cegg-price-color cegg-price-instock"]')
    for i in price[0:8]:
        pr=i.text
        Price.append(pr)

except:
    Price.append('Not Mention')

# %%
Laptops=pd.DataFrame({"Laptop Model":model, "OS":OS,"Display":Display,"Processor":Processor,
                 "Price":Price,})
print('\033[1m'+'Gaming Laptops :'+'\033[0m')
Laptops
# Out:
# Gaming Laptops :
#                                         Laptop Model               OS Display  \
# 0               Acer Aspire 7 A715-42G Ryzen 5-5500U  Windows 11 Home    15.6
# 1  MSI Gaming GF63 11SC-853IN 11th Gen Core i5-11...       Windows 11    15.6
# 2  Acer Nitro 5 AN515-57 11th Gen Core i5-11400H ...  Windows 10 Home    15.6
# 3    Lenovo Legion 5 82B500BHIN Ryzen 5-4600H (2022)  Windows 11 Home    15.6
# 4    Lenovo IdeaPad Gaming 3 11th Gen Core i5-11300H  Windows 11 Home    15.6
# 5       HP Pavilion 15-EC2146AX Ryzen 7-5800H (2021)  Windows 11 Home    16.1
# 6  HP Victus 16-d0354TX 11th Gen Core i5-11400H (...  Windows 11 Home    15.6
# 7  Dell New G15 5511 D560825WIN9B 11th Gen Core i...  Windows 11 Home    15.6
#
#                        Processor       Price
# 0              AMD Ryzen 5-5500U  Rs. 59,500
# 1  11th Gen Intel Core i5-11400H  Rs. 76,990
# 2    4th Gen AMD Ryzen 5-(4600H)  Rs. 55,490
# 3  11th Gen Intel Core i5-11300H  Rs. 80,999
# ...

# %%
//END

# %%
# Ques 7

driver = webdriver.Chrome()
url='https://www.forbes.com'
driver.get(url)

# %%
menu=driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[1]/div[1]/div/div")
menu.click()
time.sleep(2)

# %%
bill=driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[1]/div[1]/div/div[2]/ul/li[2]/div[1]")
bill.click()
time.sleep(2)

# %%
lists=driver.find_element(By.XPATH,"/html/body/div[1]/header/nav/div[1]/div[1]/div/div[2]/ul/li[2]/div[2]/div[3]/ul/li[1]/a")
lists.click()

# %%
Rank =[]
Name=[]
Net_worth=[]
Age=[]
Citizenship=[]
Source=[]
Industry=[]

# %%
rank=driver.find_elements(By.XPATH,'//div[@class="Table_rank___YBhk Table_dataCell__2QCve"]')
for i in rank:
    Rank.append(i.text)
    
name=driver.find_elements(By.XPATH,'//div[@class="TableRow_rowContainer__IC1Tv"]/div/div/div[2]/div')
for i in name:
    Name.append(i.text)
    
net=driver.find_elements(By.XPATH,'//div[@class="Table_netWorth___L4R5 Table_dataCell__2QCve"]')
for i in net:
    Net_worth.append(i.text)
    
age=driver.find_elements(By.XPATH,'//div[@class="TableRow_rowContainer__IC1Tv"]/div/div/div[4]/div')
for i in age:
    Age.append(i.text)
    
citizen=driver.find_elements(By.XPATH,'//div[@class="TableRow_rowContainer__IC1Tv"]/div/div/div[5]')
for i in citizen:
    Citizenship.append(i.text)
    
try:
    source=driver.find_elements(By.XPATH,'//div[@class="TableRow_rowContainer__IC1Tv"]/div/div/div[6]/div/span')
    for i in source:
        Source.append(i.text)
except:
    source=driver.find_elements(By.XPATH,'//*[@id="jeff-bezos"]/div[6]/div/div[1]')
    Source.append(i.text)
    
industry=driver.find_elements(By.XPATH, '//div[@class="TableRow_rowContainer__IC1Tv"]/div/div/div[7]/div')
for i in industry:
    Industry.append(i.text)

# %%
Forbes=pd.DataFrame({'Rank':Rank,'Name':Name,'Net Worth':Net_worth,'Age':Age,'Citizenship':Citizenship,
                'Source':Source,'Industry':Industry})
print('\033[1m'+' Forbes Billionaires :'+'\033[0m')
Forbes
# Out:
#  Forbes Billionaires :
#     Rank                                               Name Net Worth  \
# 0      1                           Bernard Arnault & family    $211 B
# 1      2                                     WEALTH HISTORY    $180 B
# 2      3  2\nElon Musk\n$180 B\n51\nUnited States\nTesla...    $114 B
# 3      4                                          Elon Musk    $107 B
# 4      5                                         Jeff Bezos    $106 B
# ..   ...                                                ...       ...
# 195  195                                     Autry Stephens    $9.6 B
# 196  195                                       Liu Yongxing    $9.6 B
# 197  195                                        Vinod Adani    $9.6 B
# 198  195                                      Nicolas Puech    $9.6 B
# 199  195                                 Jacques Saadé, Jr.    $9.6 B
#
#                                                    Age  \
# ...

# %%
//END

# %%
# Ques 3

driver=webdriver.Chrome()

url='https://images.google.com/'
driver.get(url)

# %%
search_bar = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
search_bar.send_keys("fruits")
select = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
select.click()

# %%
driver.execute_script("window.scrollBy(0,25000)","")

# %%
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            URL.append(source)

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\sassi\Downloads\Q3\fruits"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver=webdriver.Chrome()

url='https://images.google.com/'
driver.get(url)

# %%
search_bar = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
search_bar.send_keys("cars")
select = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
select.click()

# %%
driver.execute_script("window.scrollBy(0,25000)","")
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            URL.append(source)

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\sassi\Downloads\Q3\cars"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver=webdriver.Chrome()

url='https://images.google.com/'
driver.get(url)

# %%
search_bar = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
search_bar.send_keys("Machine Learning")
select = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
select.click()

# %%
driver.execute_script("window.scrollBy(0,25000)","")
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            URL.append(source)

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\sassi\Downloads\Q3\Machine Learning"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver=webdriver.Chrome()

url='https://images.google.com/'
driver.get(url)

# %%
search_bar = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
search_bar.send_keys("Guitar")
select = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
select.click()

# %%
driver.execute_script("window.scrollBy(0,25000)","")
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            URL.append(source)

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\sassi\Downloads\Q3\Guitar"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
driver=webdriver.Chrome()

url='https://images.google.com/'
driver.get(url)

# %%
search_bar = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea")
search_bar.send_keys("Cakes")
select = driver.find_element(By.XPATH,"/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button/div/span")
select.click()

# %%
driver.execute_script("window.scrollBy(0,25000)","")
URL=[]
images= driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            URL.append(source)

# %%
images = driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')

img_urls = []
img_data = []
for image in images:
    source= image.get_attribute('src')
    if source is not None:
        if(source[0:4] == 'http'):
            img_urls.append(source)
            
for i in range(len(img_urls)):
    if i >= 10:
        break
    print("Downloading {0} of {1} images" .format(i, 10))
    response= requests.get(img_urls[i])
    file = open(r"C:\Users\sassi\Downloads\Q3\cakes"+str(i)+".jpg", "wb")
    file.write(response.content)

# %%
//END

# %%
#Ques 8

driver=webdriver.Chrome()

url='https://www.youtube.com'
driver.get(url)

# %%
# Finding search menu by xpath
Search=driver.find_element(By.XPATH,'//input[@id="search"]') 
# Feeding input video name by user to search menu through send keys
Search.send_keys('perfect ed sheeran')
# Finding Search button for clicking through xpath
Search_button=driver.find_element(By.XPATH,'//button[@id="search-icon-legacy"]/yt-icon')  
# Clicking search button
Search_button.click()
time.sleep(2)

# %%
link = driver.find_element(By.XPATH,"//yt-formatted-string[@class ='style-scope ytd-video-renderer']")
link.click()
time.sleep(3)

# %%
comments = []
comment_time = []
Time = []
Likes = []
No_of_Likes = []

# %%
for _ in range(1000):
    driver.execute_script("window.scrollBy(0,10000)")
    

# scrape comments
cm = driver.find_elements(By.ID,"content-text")
for i in cm:
    if i.text is None:
        comments.append("--")
    else:
        comments.append(i.text)
time.sleep(4)


# scrape time when comment was posted
tm = driver.find_elements(By.XPATH,"//a[contains(text(),'ago')]")
for i in tm:
    Time.append(i.text)
    
for i in range(0,len(Time),2):
    comment_time.append(Time[i])
time.sleep(4)


# scrape the comment likes
like = driver.find_elements(By.XPATH,"//span[@class='style-scope ytd-comment-action-buttons-renderer']")
for i in like:
    Likes.append(i.text)
    
for i in range(1,len(Likes),2):
    No_of_Likes.append(Likes[i])

# %%
yt = pd.DataFrame({})
yt['Comment'] = comments[:500]
yt['Comment Time'] = comment_time[:500]
yt['Comment Upvotes'] = No_of_Likes[:500]
yt
# Out:
#                                                Comment          Comment Time  \
# 0    It's 2023, this song never gets old because ju...          15 hours ago
# 1                     Essa música é muito viciante ️️️            2 days ago
# 2    Única música capaz de me perfurar mais fundo q...             1 day ago
# 3                                             Perfeito  4 years ago (edited)
# 4              Definitely will be played at my wedding            7 days ago
# ..                                                 ...                   ...
# 495                                                              2 years ago
# 496                                        The perfect            6 days ago
# 497                                                                1 day ago
# 498              This was my proposal song to my ex-gf            6 days ago
# 499  Cuántas reproducciones tiene al año? Si tiene ...           10 days ago
#
#     Comment Upvotes
# 0               202
# ...

# %%
//END

# %%
# Ques 9

driver=webdriver.Chrome()
url="https://www.hostelworld.com"
driver.get(url)

# %%
search_bar = driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/input")
search_bar.send_keys("London")
time.sleep(3)

first = driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[2]/div/ul/li[2]/button/div[2]")
first.click()

select = driver.find_element(By.XPATH,"/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[5]/button[2]")
select.click()

# %%
hostel_name = []
distance = []
pvtprice_only = []
dormsprice_only = []
rating = []
reviews = []
over_all = []
facilities = []
description = []
npa = []
dpa = []
URL=[]

# %%
urls=driver.find_elements(By.XPATH,'//div[@class="property-card"]/a')
for i in urls[1:31]:
    Href=i.get_attribute('href')
    URL.append(Href)

# %%
try:
    dist = driver.find_elements(By.XPATH, '//div[@class="property-info-container"]/div[3]/span[2]')
    for i in dist:
        distance.append(i.text.replace('Hostel - ',''))
        
except:
    distance.append('-')
    
    
pvt = driver.find_elements(By.XPATH, '//div[@class="property-info-container"]/div[5]/div[1]/div[1]/div[2]/strong')
for i in pvt:
    p=i.text
    pvtprice_only.append(p)
    
dorms = driver.find_elements(By.XPATH, '//div[@class="property-accommodations"]/div/div[2]/div[2]')
for i in dorms:
    d=i.text 
    if d != 'Dorms From':
        dormsprice_only.append(d)
    else:
        pass
    
texts = driver.find_elements(By.XPATH, '//div[@class="accommodation-price unavailable"]')
for i in texts:
    pt=i.text
    if pt == 'No Privates Available':
        npa.append(pt)
    else:
        dpa.append(pt)


for j in npa:
    pvtprice_only.append(j)
    
for k in dpa:
    dormsprice_only.append(k)

    
    
for i in tqdm(URL[0:30]):
    driver.get(i)
    time.sleep(3)
    
    try:
        name = driver.find_elements(By.XPATH, '//div[@class="title-2"]')
        for i in name:
            hostel_name.append(i.text)
    except:
        hostel_name.append('-')
 
            
            
    
    try:
        fac1 = driver.find_elements(By.XPATH, '//div[@class="facilities-container"]/ul/li/ul/li[1]')
        for i in fac1:
            f=i.text
            facilities.append(f) 
                     
            
                
    except:
        facilities.append('-')
    
       
    
    try:
        driver.find_element(By.XPATH,"//a[@class='toggle-content']").click()
        time.sleep(4)
    except:
        pass
        
        
    
    try:
        disc = driver.find_element(By.XPATH,'//div[@class="content collapse-content"]')
        description.append(disc.text)
    except:
        over_all.append('-')
   
    

    try:
        rat = driver.find_element(By.XPATH, '//div[@class="score orange big"]')
    
        rating.append(rat.text)
    
    except:
        rating.append('-')
    

    try:
        rws = driver.find_element(By.XPATH,'//div[@class="summary orange"]/div[2]')
    
        reviews.append(rws.text.replace('Total Reviews',''))
    
        
    except:
        reviews.append('-')     
    

    try:
        overall = driver.find_element(By.XPATH,'//div[@class="keyword"]/span')
    
        over_all.append(overall.text)
    
    except:
        over_all.append('-')
# Out:
# 100%|██████████| 30/30 [02:50<00:00,  5.67s/it]

# %%
hostel = pd.DataFrame(
    {
        "Hostel Name": hostel_name,
        "Distance from City Center": distance,
        "Ratings": rating,
        "Total Review": reviews,
        "Overall Review": over_all,
        "Private Price": pvtprice_only,
        "Dorm Price": dormsprice_only,
        "Description": description,
        "Facilities": facilities,
        "URL": URL,
    }
)

hostel.head()
# Out:
#                      Hostel Name Distance from City Center Ratings  \
# 0  Palmers Lodge - Swiss Cottage  - 1.8km from city centre     9.0
# 1       St Christopher's Village  - 5.4km from city centre     8.2
# 2           Urbany Hostel London    - 3km from city centre     9.5
# 3               Generator London  - 6.1km from city centre     7.6
# 4               NX London Hostel  - 1.7km from city centre     8.0
#
#   Total Review Overall Review          Private Price Dorm Price  \
# 0       15716          Superb  No Privates Available     ₹4,877
# 1       12484        Fabulous  No Privates Available     ₹2,779
# 2         941          Superb  No Privates Available     ₹2,123
# 3        7802       Very Good                ₹11,017     ₹2,030
# 4        2002        Fabulous                ₹12,440     ₹1,768
#
#                                          Description        Facilities  \
# 0  Whether you're a backpacker, flash-packer or a...    Linen Included
# ...
